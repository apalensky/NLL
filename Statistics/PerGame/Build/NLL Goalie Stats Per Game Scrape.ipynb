# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime
import time
import csv

# %% [markdown]
# # Functions

# %%
def tableText(table):    
    """
    Returns a list of column rows and a header if applicable. 
    """
    def getRowText(tr, coltag='td'):     
        return [td.get_text(strip=True) for td in tr.find_all(coltag)]  
    rowsList = []
    tableRows = table.find_all('tr')
    tableHeader = getRowText(tableRows[0], 'th')
    if tableHeader:
        rowsList.append(tableHeader)
        tableRows = tableRows[1:]
    for i in tableRows:
        rowsList.append(getRowText(i, 'td') )       
    return rowsList

# %%
def date_conversion(date):
     return datetime.datetime.strptime(date, ' %b %d, %Y')

# %%
def addTeams(df):
    i = 0
    q = int(df[df['Name']== 'Name'].index.values) +1

    while i < len(df)-1:
        if i == (q-2):
            i += 1
        elif i == (q-1):
            df.loc[(q-2), 'Team'] = teamsList[0]
            i += 1
        elif int(df[df['Name'] == df.Name[i]].index.values) < (q-1):
            mask = int(df[df['Name'] == df.Name[i]].index.values)
            df.loc[mask, 'Team'] = teamsList[0]
            i += 1
        else:
            mask = int(df[df['Name'] == df.Name[i]].index.values)
            df.loc[mask, 'Team'] = teamsList[1]
            i += 1

# %%
def StatsTable(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    table = soup.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']=="goalies") 
    rows = table.findAll(lambda tag: tag.name=='tr')[1]
    teams = table.findAll(lambda tag: tag.name=='tr')[0]
    
    teamsList = [team.text for team in teams.findAll(lambda tag: tag.name=='td')]
    list_table = tableText(rows)
        
    dftable = pd.DataFrame(list_table[1:], columns=list_table[0])
    dftable['Gameday'] = soup.title.string
        
    split1 = dftable['Gameday'].str.split(' - ', n = 1, expand = True)
    dftable['Date'] = split1[1]
        
    split2 = split1[0].str.split(' at ', n = 1, expand = True)
    dftable['Location'] = split2[1]
    dftable.drop(columns = ['Gameday'], inplace = True)
        
    split3 = dftable['Date'].str.split(',', n = 1, expand = True)
    dftable['Day'] = split3[0]
    dftable['Date'] = split3[1]
    dftable['Date'] = dftable['Date'].apply(date_conversion)
    
    q = int(dftable[dftable['Name']== 'Name'].index.values) + 1

    for i in range(0,(len(dftable)-1)):
        if i == q-2:
            continue
        else: 
            mask = int(dftable[(dftable['Name'] == dftable.Name[i]) & 
                               (dftable['#'] == dftable['#'][i])].index.values)

            if mask < (q-1):
                dftable.loc[mask, 'Team'] = teamsList[0]
            elif mask > (q-1):
                dftable.loc[mask, 'Team'] = teamsList[1]
            
    return dftable

# %%
url = 'https://laxreports.sportlogiq.com/nll/GS179.html'
# url1 = 'https://laxreports.sportlogiq.com/nll/GS2276.html'
# url2 = 'https://laxreports.sportlogiq.com/nll/GS800.html'
# url3 = 'https://laxreports.sportlogiq.com/nll/GS900.html'
# url4 = 'https://laxreports.sportlogiq.com/nll/GS810.html'

# %%
dftable1 = StatsTable(url)
df_list = [dftable1]
dftable1.head()
# Out:
#          #                                       Name    MIN  SOG  SV Q1  \
# 0        0      D.Lee\n                        (loss)  15:00    0     37
# 1  Totals:                                      15:00      0   37      0
# 2        #                                       Name    MIN  SOG  SV Q1
# 3        0  S.LoCascio\n                        (win)  15:00    0     29
# 4  Totals:                                      15:00      0   29      0
#
#    SV Q2  SV Q3  SV Q4  SV    GA       Date  Location  Day               Team
# 0      0      0         37     0 1993-03-28  New York  Sun  Baltimore Goalies
# 1      0            37   0  None 1993-03-28  New York  Sun                NaN
# 2  SV Q2  SV Q3  SV Q4  SV    GA 1993-03-28  New York  Sun                NaN
# 3      0      0         29     0 1993-03-28  New York  Sun   New York Goalies
# 4      0            29   0  None 1993-03-28  New York  Sun                NaN

# %%
urlsList = []

for i in range(236,2277):
    url = 'https://laxreports.sportlogiq.com/nll/GS{}.html'.format(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    if bool(soup.findAll(text="html")):
        urlsList.append(url)

# %%
# Irregular formatting in box score, will add back in by hand later
urlsList.remove('https://laxreports.sportlogiq.com/nll/GS925.html')

# %%
def StatsTableUpdate(urlsList):
    for url in urlsList:
        #print(url)
        dftablei = StatsTable(url)
        # print(dftablei.head(3))
        df_list.append(dftablei)
        time.sleep(1)

# %%
#urlsList

# %%
StatsTableUpdate(urlsList)

# %%
fulldf = pd.concat(df_list, ignore_index=True)

# %%
fulldf.tail(25)
# Out:
#              #                                         Name    MIN  SOG  \
# 10269        #                                         Name    MIN  SOG
# 10270       76        W.Hill\n                        (win)  60:00   55
# 10271       35      P.Dubenski\n                        (b)
# 10272  Totals:                                        60:00     55   13
# 10273       35  C.Del Bianco\n                        (win)  60:00   49
# 10274        0      T.Richards\n                        (b)
# 10275  Totals:                                        60:00     49    5
# 10276        #                                         Name    MIN  SOG
# 10277       66       N.Rose\n                        (loss)  59:59   52
# 10278        1    R.Hutchcraft\n                        (b)
# 10279  Totals:                                        59:59     52   15
# 10280       31     Z.Higgins\n                        (win)  60:00   54
# 10281       36        B.Miller\n                        (b)
# 10282  Totals:                                        60:00     54   10
# 10283        #                                         Name    MIN  SOG
# 10284       30     M.Poulin\n                        (loss)  60:00   48
# 10285       29       K.Orleman\n                        (b)
# 10286  Totals:                                        60:00     48    7
# 10287       39      S.Fryer\n                        (loss)  60:00   44
# 10288        1         C.Wende\n                        (b)
# 10289  Totals:                                        60:00     44    7
# 10290        #                                         Name    MIN  SOG
# 10291       30     T.Carlson\n                        (win)  50:39   40
# 10292       45                                       D.Ward   9:21   12
# 10293  Totals:                                        60:00     52   12
#
#        SV Q1  SV Q2  SV Q3  SV Q4  SV    GA       Date  Location  Day  \
# 10269  SV Q1  SV Q2  SV Q3  SV Q4  SV    GA 2020-03-08   Halifax  Sun
# 10270     13     13     13      7  46     9 2020-03-08   Halifax  Sun
# 10271                                       2020-03-08   Halifax  Sun
# 10272     13     13      7     46   9  None 2020-03-08   Halifax  Sun
# 10273      5     12     13      9  39    10 2020-03-08   Toronto  Sun
# 10274                                       2020-03-08   Toronto  Sun
# 10275     12     13      9     39  10  None 2020-03-08   Toronto  Sun
# 10276  SV Q1  SV Q2  SV Q3  SV Q4  SV    GA 2020-03-08   Toronto  Sun
# 10277     15      7      9      9  40    12 2020-03-08   Toronto  Sun
# 10278                                       2020-03-08   Toronto  Sun
# 10279      7      9      9     40  12  None 2020-03-08   Toronto  Sun
# 10280     10      8     12     13  43    11 2020-03-08   Georgia  Sun
# 10281                                       2020-03-08   Georgia  Sun
# 10282      8     12     13     43  11  None 2020-03-08   Georgia  Sun
# 10283  SV Q1  SV Q2  SV Q3  SV Q4  SV    GA 2020-03-08   Georgia  Sun
# 10284      7     15      7      7  36    12 2020-03-08   Georgia  Sun
# 10285                                       2020-03-08   Georgia  Sun
# 10286     15      7      7     36  12  None 2020-03-08   Georgia  Sun
# 10287      7     14      6      7  34    10 2020-03-08  Colorado  Sun
# 10288                                       2020-03-08  Colorado  Sun
# 10289     14      6      7     34  10  None 2020-03-08  Colorado  Sun
# 10290  SV Q1  SV Q2  SV Q3  SV Q4  SV    GA 2020-03-08  Colorado  Sun
# 10291      5      7     10     15  37     3 2020-03-08  Colorado  Sun
# 10292      7                        7     5 2020-03-08  Colorado  Sun
# 10293      7     10     15     44   8  None 2020-03-08  Colorado  Sun
#
#                        Team SV OT
# 10269                   NaN   NaN
# 10270       Halifax Goalies   NaN
# 10271       Halifax Goalies   NaN
# 10272                   NaN   NaN
# 10273       Calgary Goalies   NaN
# 10274       Calgary Goalies   NaN
# 10275                   NaN   NaN
# 10276                   NaN   NaN
# 10277       Toronto Goalies   NaN
# 10278       Toronto Goalies   NaN
# 10279                   NaN   NaN
# 10280  Philadelphia Goalies   NaN
# 10281  Philadelphia Goalies   NaN
# 10282                   NaN   NaN
# 10283                   NaN   NaN
# 10284       Georgia Goalies   NaN
# 10285       Georgia Goalies   NaN
# 10286                   NaN   NaN
# 10287     Rochester Goalies   NaN
# 10288     Rochester Goalies   NaN
# 10289                   NaN   NaN
# 10290                   NaN   NaN
# 10291      Colorado Goalies   NaN
# 10292      Colorado Goalies   NaN
# 10293                   NaN   NaN

# %%
#fulldf.to_csv('NLLGoaliesGameStats.csv')
