# %% [markdown]
# ## NLL Floor Players Stats Cleaning

# %% [markdown]
# Work by Alexander Palensky
#
# For questions,
# contact me on [Twitter](https://twitter.com/AlPalensky)
# or view my [Kaggle Account](https://www.kaggle.com/apalensky) for supplemental content

# %%
import numpy as np
import pandas as pd
import datetime
from datetime import date
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('NLLFloorPlayersGameStats.csv')

# %%
split1 = df['Name'].str.split('\n ', n = 1, expand = True)
df['Name'] = split1[0]
df['Captain'] = split1[1]

# %%
df = df[(df.Name != 'Totals:') & (df['Name'] != 'Name')]
df.head(20)
# Out:
#     Unnamed: 0  #           Name  G  A +/- PIM  S SOFF  LB  T CT   FO  TOF  \
# 0            0  0        T.Welsh  2  0   0   4  0    0   3  0  0    -  NaN
# 1            1  0        P.Welsh  0  0   0   2  0    0   5  0  0    -  NaN
# 2            2  0       J.Tucker  2  0   0   2  0    0   6  0  0    -  NaN
# 3            3  0       R.Sowell  0  0   0   0  0    0   0  0  0    -  NaN
# 4            4  0        D.Smith  0  0   0   0  0    0   3  0  0    -  NaN
# 5            5  0       T.Millon  1  0   0   2  0    0   2  0  0    -  NaN
# 6            6  0       B.Marino  1  1   0   0  0    0   1  0  0    -  NaN
# 7            7  0        T.Manos  0  0   0   0  0    0   0  0  0    -  NaN
# 8            8  0  B.Kroneberger  1  0   0   0  0    0   2  0  0    -  NaN
# 9            9  0      M.Kerwick  1  0   0   0  0    0   0  0  0    -  NaN
# 10          10  0      J.Jackson  0  0   0   0  0    0   2  0  0  3-3  NaN
# 11          11  0         F.Haas  0  1   0   0  0    0   0  0  0  7-7  NaN
# 12          12  0        R.Fried  0  1   0   0  0    0   0  0  0    -  NaN
# 13          13  0        T.Curry  0  2   0   2  0    0   2  0  0    -  NaN
# 14          14  0      D.Britton  0  1   0   0  0    0   2  0  0  2-2  NaN
# 15          15  0     J.Blanding  1  0   0   0  0    0   5  0  0    -  NaN
# 16          16  0      V.Angotti  0  0   0   0  0    0   7  0  0    -  NaN
# 17          17  0          D.Lee  0  0   0   0  0    0   2  0  0    -  NaN
# 20          20  0      V.Pfeifer  0  0   0   0  0    0   0  0  0    -  NaN
# 21          21  0    V.Sombrotto  0  0   0   0  0    0  12  0  0    -  NaN
#
#           Date  Location  Day              Team Captain
# 0   1993-03-28  New York  Sun  Baltimore Roster    None
# 1   1993-03-28  New York  Sun  Baltimore Roster    None
# 2   1993-03-28  New York  Sun  Baltimore Roster    None
# 3   1993-03-28  New York  Sun  Baltimore Roster    None
# 4   1993-03-28  New York  Sun  Baltimore Roster    None
# 5   1993-03-28  New York  Sun  Baltimore Roster    None
# 6   1993-03-28  New York  Sun  Baltimore Roster    None
# 7   1993-03-28  New York  Sun  Baltimore Roster    None
# 8   1993-03-28  New York  Sun  Baltimore Roster    None
# 9   1993-03-28  New York  Sun  Baltimore Roster    None
# 10  1993-03-28  New York  Sun  Baltimore Roster    None
# 11  1993-03-28  New York  Sun  Baltimore Roster    None
# 12  1993-03-28  New York  Sun  Baltimore Roster    None
# 13  1993-03-28  New York  Sun  Baltimore Roster    None
# 14  1993-03-28  New York  Sun  Baltimore Roster    None
# 15  1993-03-28  New York  Sun  Baltimore Roster    None
# 16  1993-03-28  New York  Sun  Baltimore Roster    None
# 17  1993-03-28  New York  Sun  Baltimore Roster    None
# 20  1993-03-28  New York  Sun   New York Roster    None
# 21  1993-03-28  New York  Sun   New York Roster    None

# %%
df = df.reset_index()
df.head(20)
# Out:
#     index  Unnamed: 0  #           Name  G  A +/- PIM  S SOFF  LB  T CT   FO  \
# 0       0           0  0        T.Welsh  2  0   0   4  0    0   3  0  0    -
# 1       1           1  0        P.Welsh  0  0   0   2  0    0   5  0  0    -
# 2       2           2  0       J.Tucker  2  0   0   2  0    0   6  0  0    -
# 3       3           3  0       R.Sowell  0  0   0   0  0    0   0  0  0    -
# 4       4           4  0        D.Smith  0  0   0   0  0    0   3  0  0    -
# 5       5           5  0       T.Millon  1  0   0   2  0    0   2  0  0    -
# 6       6           6  0       B.Marino  1  1   0   0  0    0   1  0  0    -
# 7       7           7  0        T.Manos  0  0   0   0  0    0   0  0  0    -
# 8       8           8  0  B.Kroneberger  1  0   0   0  0    0   2  0  0    -
# 9       9           9  0      M.Kerwick  1  0   0   0  0    0   0  0  0    -
# 10     10          10  0      J.Jackson  0  0   0   0  0    0   2  0  0  3-3
# 11     11          11  0         F.Haas  0  1   0   0  0    0   0  0  0  7-7
# 12     12          12  0        R.Fried  0  1   0   0  0    0   0  0  0    -
# 13     13          13  0        T.Curry  0  2   0   2  0    0   2  0  0    -
# 14     14          14  0      D.Britton  0  1   0   0  0    0   2  0  0  2-2
# 15     15          15  0     J.Blanding  1  0   0   0  0    0   5  0  0    -
# 16     16          16  0      V.Angotti  0  0   0   0  0    0   7  0  0    -
# 17     17          17  0          D.Lee  0  0   0   0  0    0   2  0  0    -
# 18     20          20  0      V.Pfeifer  0  0   0   0  0    0   0  0  0    -
# 19     21          21  0    V.Sombrotto  0  0   0   0  0    0  12  0  0    -
#
#     TOF        Date  Location  Day              Team Captain
# 0   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 1   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 2   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 3   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 4   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 5   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 6   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 7   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 8   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 9   NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 10  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 11  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 12  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 13  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 14  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 15  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 16  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 17  NaN  1993-03-28  New York  Sun  Baltimore Roster    None
# 18  NaN  1993-03-28  New York  Sun   New York Roster    None
# 19  NaN  1993-03-28  New York  Sun   New York Roster    None

# %%
split2 = df['FO'].str.split('-', n = 1, expand = True)

df['FO_W'] = split2[0]
df['FO_L'] = split2[1]

df.tail()
# Out:
#        index  Unnamed: 0   #       Name  G  A  +/- PIM  S SOFF LB  T CT FO  \
# 55146  59618       59618  82   J.Cupido  0  0   -3   0  2    0  6  2  1  -
# 55147  59619       59619  86    J.Lintz  0  0   -1   2  0    0  1  0  0  -
# 55148  59620       59620  91   J.McNabb  0  2    4   0  3    4  2  2  1  -
# 55149  59621       59621  30  T.Carlson  0  0  NaN   0  0    0  3  1  0  -
# 55150  59622       59622  45     D.Ward  0  0  NaN   0  0    0  1  0  0  -
#
#          TOF        Date  Location  Day             Team  \
# 55146  18:07  2020-03-08  Colorado  Sun  Colorado Roster
# 55147  16:21  2020-03-08  Colorado  Sun  Colorado Roster
# 55148  11:03  2020-03-08  Colorado  Sun  Colorado Roster
# 55149    NaN  2020-03-08  Colorado  Sun  Colorado Roster
# 55150    NaN  2020-03-08  Colorado  Sun  Colorado Roster
#
#                            Captain FO_W FO_L
# 55146                          (A)
# 55147                         None
# 55148                         None
# 55149                         None
# 55150                         None

# %%
df = df[df.columns[[17, 15, 16, 2, 3, 19, 18, 4, 5, 6, 7, 8, 9, 10 , 11, 12, 20, 21, 14]]]

# %%
df.rename(columns={"FO_L": "FO"}, inplace = True)

# %%
split3 = df['Team'].str.split('Roster', n = 1, expand = True)
df['Team'] = split3[0]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.tail()
# Out:
#        Day       Date  Location   #       Name                      Captain  \
# 55146  Sun 2020-03-08  Colorado  82   J.Cupido                          (A)
# 55147  Sun 2020-03-08  Colorado  86    J.Lintz                         None
# 55148  Sun 2020-03-08  Colorado  91   J.McNabb                         None
# 55149  Sun 2020-03-08  Colorado  30  T.Carlson                         None
# 55150  Sun 2020-03-08  Colorado  45     D.Ward                         None
#
#             Team  G  A  +/- PIM  S SOFF LB  T CT FO_W FO    TOF
# 55146  Colorado   0  0   -3   0  2    0  6  2  1          18:07
# 55147  Colorado   0  0   -1   2  0    0  1  0  0          16:21
# 55148  Colorado   0  2    4   0  3    4  2  2  1          11:03
# 55149  Colorado   0  0  NaN   0  0    0  3  1  0            NaN
# 55150  Colorado   0  0  NaN   0  0    0  1  0  0            NaN

# %%
for i in range(0,len(df)):
    if df['+/-'][i] == 'NaN':
        df.loc[i, '+/-'] = None
    if df.FO_W[i] == '':
        df.loc[i, 'FO_W'] = None
    if df.FO[i] == '':
        df.loc[i, 'FO'] = None
    if df.TOF[i] == 'NaN':
        df.loc[i, 'TOF'] = None

# %%
for i in range(0,len(df)):
    if df.Captain[i] == None:
        continue
    else:
        df.loc[i, 'Captain'] = df.Captain[i].strip().replace('(','').replace(')','')

# %%
df[["G", "A", "+/-", "PIM", "S", "SOFF", "LB", "T", "CT", "FO_W", "FO"]] = df[["G", "A", "+/-", "PIM", "S", "SOFF", "LB", "T", "CT", "FO_W", "FO",]].apply(pd.to_numeric)

# %%
for i in range(0, len(df)):
    if type(df.TOF[i]) == float:
        continue
    else:
        df.loc[i, 'TOF'] = int((df['TOF'][i]).split(':')[0]) + (int((df['TOF'][i]).split(':')[1]) / 60)

# %%
df.tail(50)
# Out:
#        Day       Date  Location   #          Name Captain        Team  G  A  \
# 55101  Sun 2020-03-08   Georgia  21    B.Bomberry    None    Georgia   0  1
# 55102  Sun 2020-03-08   Georgia  24   J.MacIntosh       C    Georgia   0  0
# 55103  Sun 2020-03-08   Georgia  25     L.Stouros    None    Georgia   0  0
# 55104  Sun 2020-03-08   Georgia  27   A.Wiedemann    None    Georgia   1  0
# 55105  Sun 2020-03-08   Georgia  28    Z.Williams    None    Georgia   1  0
# 55106  Sun 2020-03-08   Georgia  32     S.Jackson       A    Georgia   3  3
# 55107  Sun 2020-03-08   Georgia  44      C.Tutton    None    Georgia   0  0
# 55108  Sun 2020-03-08   Georgia  45       J.Noble       A    Georgia   0  0
# 55109  Sun 2020-03-08   Georgia  55        B.Cole    None    Georgia   1  0
# 55110  Sun 2020-03-08   Georgia  83      R.Staats    None    Georgia   4  3
# 55111  Sun 2020-03-08   Georgia  29     K.Orleman    None    Georgia   0  0
# 55112  Sun 2020-03-08   Georgia  30      M.Poulin    None    Georgia   0  1
# 55113  Sun 2020-03-08  Colorado   2      P.Dawson       C  Rochester   1  0
# 55104 -2.0    0   2     1   6  1   1   NaN   NaN  11.3167
# 55105  4.0    0   6     4   3  3   0   NaN   NaN  19.7333
# 55106  6.0    2  10     4   5  2   0   NaN   NaN  24.0667
# 55107 -3.0    4   0     1   6  0   2   NaN   NaN     14.9
# 55108 -5.0    0   1     0   3  0   1   NaN   NaN  13.1667
# 55109 -4.0    2   1     1   0  1   1   NaN   NaN     14.6
# 55110  7.0    0  11     7   6  2   1   NaN   NaN  19.8833
# 55111  NaN    0   0     0   0  0   0   NaN   NaN      NaN
# 55112  NaN    0   0     0   0  0   0   NaN   NaN      NaN
# 55113 -2.0    2   1     0   7  0   1   NaN   NaN     18.4
# 55114 -2.0    0   1     0   5  0   0   NaN   NaN    14.55
# 55115  2.0    0   8     5   4  2   0   NaN   NaN     21.9
# 55116  3.0    0  13     5   9  2   0   NaN   NaN  25.1833
# 55117 -1.0    0   2     0   2  0   0   NaN   NaN    13.25
# 55118 -1.0    0   1     0   7  1   2   NaN   NaN  19.1833
# 55119  3.0    2   9     7   3  2   0   NaN   NaN  20.3667
# 55120 -3.0    0   0     0   7  0   0   NaN   NaN  19.5167
# 55121  2.0    0   4     2   3  3   0   NaN   NaN  12.2167
# 55122  2.0    2   1     1   1  0   0   NaN   NaN  15.8667
# 55123 -3.0    0   0     0   2  1   0   NaN   NaN  19.0833
# 55124 -4.0    0   0     1   3  1   1   NaN   NaN  18.2833
# 55125  2.0    0   4     3   6  2   0   NaN   NaN  20.6333
# 55126 -1.0    2   1     0   3  0   0   NaN   NaN  14.6833
# 55127 -1.0    0   1     0   3  0   0   8.0  14.0  12.9833
# 55128 -3.0    0   1     0   2  0   0   2.0   8.0  13.2667
# 55129  2.0    0   5     4   2  1   0   NaN   NaN  17.6333
# 55130  NaN    0   0     0   0  0   0   NaN   NaN      NaN
# 55131  NaN    0   0     0   1  0   0   NaN   NaN      NaN
# 55132  1.0    0   0     0   1  0   0  11.0  17.0  14.4833
# 55133 -3.0    0   1     0   2  0   1   NaN   NaN  12.5667
# 55134  3.0    0   3     3   1  0   0   NaN   NaN  14.4667
# 55135 -4.0    4   0     0   5  0   0   NaN   NaN  16.4333
# 55136 -1.0    0   0     0   5  0   0   NaN   NaN  16.8167
# 55137  5.0    0  11     6   6  1   0   NaN   NaN  23.3667
# 55138  4.0    0   7     6   6  2   1   NaN   NaN  20.4833
# 55139 -4.0    4   0     0   7  0   1   NaN   NaN  22.8833
# 55140  4.0    0   5     1   4  0   0   NaN   NaN    16.75
# 55141 -2.0    0   1     0   2  2   1   NaN   NaN  18.5333
# 55142 -1.0    0   0     1   4  0   0   NaN   NaN  17.0167
# 55143 -4.0    2   0     0   2  0   0   1.0   5.0  19.7833
# 55144  5.0    0   9     1   1  5   0   NaN   NaN    22.75
# 55145  3.0    0   2     0   1  2   0   NaN   NaN     11.4
# 55146 -3.0    0   2     0   6  2   1   NaN   NaN  18.1167
# 55147 -1.0    2   0     0   1  0   0   NaN   NaN    16.35
# 55148  4.0    0   3     4   2  2   1   NaN   NaN    11.05
# 55149  NaN    0   0     0   3  1   0   NaN   NaN      NaN
# 55150  NaN    0   0     0   1  0   0   NaN   NaN      NaN

# %%
#df.to_csv('CleanedNLLFloorPlayersGameStats.csv')
